# %%
import pandas as pd
import numpy as np
import math
from datetime import datetime
import ast

def calculate_recency_scores(df):
    df_copy = df.copy()
    current_date = datetime.now()
    
    for idx, row in df_copy.iterrows():
        scores = calculate_row_recency_scores(row, current_date)
        
        for score_col, score_val in scores.items():
            df_copy.at[idx, score_col] = score_val
    
    return df_copy

def calculate_row_recency_scores(row, current_date):
    scores = {}
    
    address_indices = []
    n = 0
    max_checks = 10  
    
    while n < max_checks:
        address_col = f'Address.{n}.completeAddress'
        if address_col in row and pd.notna(row[address_col]) and str(row[address_col]).strip() != '':
            address_indices.append(n)
        n += 1
    
    if not address_indices:
        return scores
    
    all_address_types = []
    for i in address_indices:
        types = get_address_types(row, i)
        all_address_types.extend(types)
    
    unique_types_count = len(set(all_address_types)) if all_address_types else 1
    
    for i in address_indices:
        score = calculate_single_address_score(row, i, current_date, unique_types_count)
        address_text = str(row[f'Address.{i}.completeAddress']).strip()
        
        scores[f'Address.{i}_recency_score'] = round(score, 2)
        scores[f'Address.{i}_address_text'] = address_text
    
    return scores

def get_address_types(row, address_index):
  
    prefix = f'Address.{address_index}'
    types_field = f'{prefix}.addressType'
    
    if types_field not in row or pd.isna(row[types_field]):
        return []
    
    types_value = row[types_field]
    
    if isinstance(types_value, list):
        return types_value
    elif isinstance(types_value, str):
        types_value = types_value.strip()
        if types_value.startswith('[') and types_value.endswith(']'):
            try:
                return ast.literal_eval(types_value)
            except:
                return [types_value.strip("[]'\"")]
        else:
            return [types_value]
    else:
        return []

def calculate_single_address_score(row, address_index, current_date, unique_types_count):
    """
    Calculate recency score for a single address
    """
    prefix = f'Address.{address_index}'
    
    # 1. Temporal Score (40%)
    temporal_score = calculate_temporal_score(row, prefix, current_date)
    
    # 2. Frequency Score (25%)
    frequency_score = calculate_frequency_score(row, prefix)
    
    # 3. Usage Pattern Score (20%)
    pattern_score = calculate_pattern_score(row, address_index)
    
    # 4. Consistency Score (10%)
    consistency_score = calculate_consistency_score(unique_types_count)
    
    # 5. Quality Impact (5%)
    quality_score = calculate_quality_score(row, prefix)
    
    # Final weighted calculation
    final_score = (
        temporal_score * 0.40 +
        frequency_score * 0.25 +
        pattern_score * 0.20 +
        consistency_score * 0.10 +
        quality_score * 0.05
    )
    
    return final_score

def calculate_temporal_score(row, prefix, current_date):
    delivery_date_field = f'{prefix}.lastDeliveryDate'
    
    if delivery_date_field not in row or pd.isna(row[delivery_date_field]):
        return 0
    
    try:
        delivery_date = pd.to_datetime(row[delivery_date_field])
        
        if delivery_date.tz is not None:
            delivery_date = delivery_date.tz_convert('UTC').tz_localize(None)
        
        if hasattr(current_date, 'tz') and current_date.tz is not None:
            current_date = current_date.tz_localize(None)
        
        days_diff = (current_date - delivery_date).days
        
        if days_diff <= 7:
            return 100
        elif days_diff <= 90:
            return 50 + 35 * math.exp(-0.05 * (days_diff - 7))
        elif days_diff <= 365:
            return max(5, 20 - 15 * ((days_diff - 90) / 275))
        else:
            return 5
    except Exception as e:
        return 0

def calculate_frequency_score(row, prefix):
    times_seen_field = f'{prefix}.timesSeen'
    
    if times_seen_field not in row or pd.isna(row[times_seen_field]):
        times_seen = 0
    else:
        times_seen = int(row[times_seen_field])
    
    if times_seen == 1:
        return 40
    elif times_seen <= 3:
        return 40 + (times_seen - 1) * 20
    elif times_seen <= 10:
        return 80 + (times_seen - 3) * 2.4
    else:
        return min(100, 97 + (times_seen - 10) * 0.3)

def calculate_pattern_score(row, address_index):
    """
    Calculate usage pattern score based on address type
    """
    address_types = get_address_types(row, address_index)
    
    type_scores = {
        'logisticsAddress': 90,        # High recency importance - active delivery
        'transportDlAddress': 75,      # Moderate - government registered, changes occasionally  
        'taxAddress': 80,              # High - tax filing addresses change when business moves
        'businessAddress': 85,         # High - business operations, moderate change frequency
        'temporaryAddress': 95,        # Highest - by definition temporary
        'billingAddress': 70,          # Moderate - billing addresses change less frequently
        'permanentAddress': 40         # Low - permanent by definition
    }
    
    if not address_types:
        return 60  
    
    scores = [type_scores.get(addr_type, 60) for addr_type in address_types]
    return max(scores)

def calculate_consistency_score(unique_types_count):
    if unique_types_count == 1:
        return 85
    elif unique_types_count == 2:
        return 70
    elif unique_types_count == 3:
        return 55
    else:
        return 40

def calculate_quality_score(row, prefix):
    completeness_field = f'{prefix}.completeAddress.addressCompletenessScore'
    
    if completeness_field not in row or pd.isna(row[completeness_field]):
        return 40  # Default low score
    
    completeness = float(row[completeness_field])
    
    if completeness >= 80:
        return 100
    elif completeness >= 60:
        return 85
    elif completeness >= 40:
        return 70
    elif completeness >= 20:
        return 55
    else:
        return 40

def analyze_results(df_with_scores):
    score_cols = [col for col in df_with_scores.columns if col.endswith('_recency_score')]
    address_text_cols = [col for col in df_with_scores.columns if col.endswith('_address_text')]
    
    if not score_cols:
        print("No recency scores found!")
        return
    
    print("=== RECENCY SCORE ANALYSIS ===\n")
    
    all_scores = []
    for col in score_cols:
        all_scores.extend(df_with_scores[col].dropna().tolist())
    
    if all_scores:
        print(f"Total addresses scored: {len(all_scores)}")
        print(f"Average recency score: {np.mean(all_scores):.2f}")
        print(f"Score range: {min(all_scores):.2f} - {max(all_scores):.2f}")
        print(f"Standard deviation: {np.std(all_scores):.2f}\n")
        
        print("Score Distribution:")
        print(f"Excellent (90-100): {sum(1 for s in all_scores if s >= 90)} addresses")
        print(f"Good (75-89): {sum(1 for s in all_scores if 75 <= s < 90)} addresses")
        print(f"Fair (60-74): {sum(1 for s in all_scores if 60 <= s < 75)} addresses")
        print(f"Poor (40-59): {sum(1 for s in all_scores if 40 <= s < 60)} addresses")
        print(f"Very Poor (0-39): {sum(1 for s in all_scores if s < 40)} addresses")
    
    print(f"\n=== SAMPLE RESULTS ===")
    
    display_cols = ['name', 'email']
    
    # Add score and address pairs in order
    for i in range(10):  # Check up to Address.9
        score_col = f'Address.{i}_recency_score'
        addr_col = f'Address.{i}_address_text'
        if score_col in df_with_scores.columns:
            display_cols.extend([score_col, addr_col])
    
    available_cols = [col for col in display_cols if col in df_with_scores.columns]
    
    sample_df = df_with_scores[available_cols].head(10)
    
    # Display in a more readable format
    for idx, row in sample_df.iterrows():
        print(f"\n--- {row['name']} ({row['email']}) ---")
        for col in available_cols:
            if col.endswith('_recency_score') and pd.notna(row[col]):
                addr_idx = col.split('.')[1].split('_')[0]
                addr_text_col = f'Address.{addr_idx}_address_text'
                addr_text = row.get(addr_text_col, 'N/A')
                print(f"  Score: {row[col]:.2f} | Address: {str(addr_text)[:80]}...")
        
        if idx >= 4:  # Show only first 5 rows in detail
            break
    
    return df_with_scores[score_cols].describe()

# Main execution function
def run_recency_analysis(file_path):
    """
    Main function to run the complete recency analysis
    """
    try:
        # Load the data
        print("Loading data...")
        df = pd.read_csv(file_path)
        print(f"Loaded {len(df)} rows and {len(df.columns)} columns")
        
        # Check for address columns
        address_cols = [col for col in df.columns if 'Address.' in col and 'completeAddress' in col]
        print(f"Found {len(address_cols)} address columns: {address_cols[:5]}...")  # Show first 5
        
        # Calculate recency scores
        print("\nCalculating recency scores...")
        df_with_scores = calculate_recency_scores(df)
        
        # Analyze results
        stats = analyze_results(df_with_scores)
        
        return df_with_scores, stats
        
    except Exception as e:
        print(f"Error: {str(e)}")
        return None, None

# Usage example:
if __name__ == "__main__":
    # Run the analysis
    file_path = "DCB_AlternateAddress.csv"
    df_result, statistics = run_recency_analysis(file_path)
    
    if df_result is not None:
        print(f"\n=== DETAILED STATISTICS ===")
        print(statistics)
# Out:
# Loading data...
# Loaded 4455 rows and 447 columns
# Found 75 address columns: ['Address.0.completeAddress', 'Address.0.completeAddress.addressCompletenessScore', 'Address.0.completeAddress.inputAddressSimilarityScore', 'Address.1.completeAddress', 'Address.1.completeAddress.addressCompletenessScore']...
#
# Calculating recency scores...
# /var/folders/_3/j4fdj65x1hxdgmd_3jkytp980000gn/T/ipykernel_69602/510496620.py:306: DtypeWarning: Columns (146,149,162,194,197,200,201,202,203,204,205,207,208,209,210,212,213,216,217,218,219,220,221,223,224,225,226,228,229,232,233,234,235,236,237,239,240,241,242,244,245,248,249,250,251,252,253,255,256,257,258,260,261,264,265,266,267,268,269,271,272,273,274,276,277,280,281,282,283,284,285,287,288,289,290,292,293,296,297,298,299,300,301,303,304,305,308,312,313,314,315,316,317,319,320,321,324,327,328,329,330,331,332,334,335,336,339,342,343,344,345,346,347,349,350,351,354,355,357,358,359,360,361,362,364,365,366,367,369,370,372,373,374,375,376,377,379,380,381,382,384,385,387,388,389,390,391,392,394,395,396,397,399,400,402,403,404,405,406,407,409,410,411,412,414,415,417,418,419,420,421,422,424,425,426,427,429,430,432,433,434,435,436,437,439,440,441,444) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# === RECENCY SCORE ANALYSIS ===
#
# Total addresses scored: 9435
# Average recency score: 38.50
# Score range: 28.75 - 61.27
# Standard deviation: 4.38
#
# Score Distribution:
# Excellent (90-100): 0 addresses
# Good (75-89): 0 addresses
# Fair (60-74): 6 addresses
# Poor (40-59): 3046 addresses
# Very Poor (0-39): 6383 addresses
#
# === SAMPLE RESULTS ===
#
# --- nan (mor27nov@gmail.com) ---
#   Score: 41.00 | Address: 770/28 bharat colony rohtak near shella by pass chock.,House,Rohtak,Haryana,Indi...
#   Score: 44.39 | Address: Sec 36 om enclave near toll tax makroli rohtak Gohana road,Rohtak,Haryana,India,...
#
# --- nan (sajid9350249895@gmail.com) ---
#   Score: 38.25 | Address: Masjid Hadi Ali Shah,Central Delhi,Delhi,India,110055,DL,IN...
#
# --- nan (vishalkewat9755@gmail.com) ---
#   Score: 38.25 | Address: 10 kaladev,10 kaladev,Kaladev dashera madan,Vidisha,Madhya Pradesh,India,464114,...
#   Score: 38.25 | Address: Vidisha tashsil lateari thana kaladev,Dasehra Medan kaladev,Vidisha,Madhya Prade...
#
# --- nan (nan) ---
#   Score: 45.25 | Address: EASLAND ENCLAVE,BLOCK-5,FLAT-502,FIFTH FLOOR,S.A. ROAD,ELAMKULAM,KADAVANTHRA P.O...
#   Score: 38.75 | Address: CROMA KALAMASSERY NEAR CUSAT METRO STATION METRO P,ILLAR 311 SOUTH KALAMASSERY,E...
#   Score: 39.50 | Address: Easland Enclave,Block-5,Flat No 502,Elamkulam,Kadavanthara,Kadavanthara,Ernakula...
#   Score: 33.00 | Address: 8 924  6 424,KANJIRAKKATTU,THRIKKAKKARA,0...
#
# --- nan (nan) ---
#   Score: 38.25 | Address: Golden City Road,1st cross,Collector office back side,Thanthonimalaik,30/2,Karur...
#
# === DETAILED STATISTICS ===
#        Address.0_recency_score  Address.1_recency_score  \
# count              4455.000000              2175.000000
# mean                 38.986175                38.364023
# std                   4.711056                 4.301239
# min                  28.750000                29.500000
# 25%                  35.250000                35.250000
# 50%                  39.000000                38.250000
# 75%                  41.000000                40.250000
# max                  61.270000                60.730000
#
#        Address.2_recency_score  Address.3_recency_score  \
# count              1121.000000               649.000000
# mean                 37.896940                37.671710
# std                   3.699512                 3.776334
# min                  29.500000                29.500000
# 25%                  36.750000                36.000000
# 50%                  38.250000                38.250000
# 75%                  39.500000                39.000000
# max                  57.350000                55.400000
#
#        Address.4_recency_score  Address.5_recency_score  \
# count               393.000000               250.000000
# mean                 37.895776                37.987440
# std                   4.053402                 4.062759
# min                  29.500000                30.250000
# 25%                  36.750000                36.750000
# 50%                  38.250000                38.250000
# 75%                  39.000000                39.000000
# max                  52.660000                55.100000
#
#        Address.6_recency_score  Address.7_recency_score  \
# count               168.000000               105.000000
# mean                 37.394524                38.159905
# std                   3.103070                 3.139781
# min                  30.250000                30.250000
# 25%                  36.562500                36.750000
# 50%                  38.250000                38.250000
# 75%                  38.437500                39.000000
# max                  49.750000                54.480000
#
#        Address.8_recency_score  Address.9_recency_score
# count                69.000000                50.000000
# mean                 37.525072                38.736800
# std                   3.644564                 3.584564
# min                  30.250000                31.750000
# 25%                  36.750000                37.687500
# 50%                  38.250000                38.250000
# 75%                  39.000000                39.000000
# max                  49.750000                50.950000

# %%
import pandas as pd
import numpy as np
import math
from datetime import datetime
import ast

def calculate_recency_scores(df):
    """
    Calculate recency scores for all Address.N.completeAddress fields in the dataframe
    """
    df_copy = df.copy()
    current_date = datetime.now()
    
    # Counter for detailed logging
    address_counter = 0
    
    print("\n" + "="*80)
    print("🔍 DETAILED SCORING BREAKDOWN FOR FIRST 3 ADDRESSES")
    print("="*80)
    
    # Process each row
    for idx, row in df_copy.iterrows():
        scores = calculate_row_recency_scores(row, current_date, address_counter)
        
        # Add scores as new columns
        for score_col, score_val in scores.items():
            df_copy.at[idx, score_col] = score_val
            
            # Update counter for logging
            if score_col.endswith('_recency_score'):
                address_counter += 1
    
    print("="*80)
    print("✅ DETAILED LOGGING COMPLETE")
    print("="*80 + "\n")
    
    return df_copy

def calculate_row_recency_scores(row, current_date, address_counter=0):
    """
    Calculate recency scores for all addresses in a single row
    """
    scores = {}
    
    # Find all valid addresses for this row
    address_indices = []
    n = 0
    max_checks = 10  # Reasonable limit to avoid infinite loops
    
    while n < max_checks:
        address_col = f'Address.{n}.completeAddress'
        if address_col in row and pd.notna(row[address_col]) and str(row[address_col]).strip() != '':
            address_indices.append(n)
        n += 1
    
    if not address_indices:
        return scores
    
    # Collect all address types for consistency scoring
    all_address_types = []
    for i in address_indices:
        types = get_address_types(row, i)
        all_address_types.extend(types)
    
    unique_types_count = len(set(all_address_types)) if all_address_types else 1
    
    # Calculate score and extract address text for each valid address
    for i in address_indices:
        score = calculate_single_address_score(row, i, current_date, unique_types_count, address_counter)
        address_text = str(row[f'Address.{i}.completeAddress']).strip()
        
        scores[f'Address.{i}_recency_score'] = round(score, 2)
        scores[f'Address.{i}_address_text'] = address_text
        
        address_counter += 1
    
    return scores

def get_address_types(row, address_index):
    """
    Extract address types from the addressType field
    """
    prefix = f'Address.{address_index}'
    types_field = f'{prefix}.addressType'
    
    if types_field not in row or pd.isna(row[types_field]):
        return []
    
    types_value = row[types_field]
    
    # Handle different formats
    if isinstance(types_value, list):
        return types_value
    elif isinstance(types_value, str):
        types_value = types_value.strip()
        if types_value.startswith('[') and types_value.endswith(']'):
            try:
                return ast.literal_eval(types_value)
            except:
                # If parsing fails, treat as single string
                return [types_value.strip("[]'\"")]
        else:
            return [types_value]
    else:
        return []

def calculate_single_address_score(row, address_index, current_date, unique_types_count, global_address_counter=0):
    """
    Calculate recency score for a single address
    """
    prefix = f'Address.{address_index}'
    
    # Enable detailed logging for first 3 addresses
    log_details = global_address_counter < 3
    
    if log_details:
        print(f"\n🏠 ADDRESS #{global_address_counter + 1} SCORING BREAKDOWN")
        print("-" * 60)
        # Handle potential NaN values in name and email
        user_name = row.get('name', 'Unknown')
        if pd.isna(user_name):
            user_name = row.get('nameoftheindividual', 'Unknown')
        if pd.isna(user_name):
            user_name = 'Unknown'
            
        user_email = row.get('email', 'No email')
        if pd.isna(user_email):
            user_email = 'No email'
            
        address_text = str(row.get(f'{prefix}.completeAddress', 'N/A'))
        print(f"👤 User: {user_name} ({user_email})")
        print(f"📍 Address: {address_text[:70]}...")
        print(f"🔢 Address Index: {prefix}")
        print("-" * 60)
    
    # 1. Temporal Score (40%)
    temporal_score = calculate_temporal_score(row, prefix, current_date, log_details)
    
    # 2. Frequency Score (25%)
    frequency_score = calculate_frequency_score(row, prefix, log_details)
    
    # 3. Usage Pattern Score (20%)
    pattern_score = calculate_pattern_score(row, address_index, log_details)
    
    # 4. Consistency Score (10%)
    consistency_score = calculate_consistency_score(unique_types_count, log_details)
    
    # 5. Quality Impact (5%)
    quality_score = calculate_quality_score(row, prefix, log_details)
    
    # Final weighted calculation
    final_score = (
        temporal_score * 0.40 +
        frequency_score * 0.25 +
        pattern_score * 0.20 +
        consistency_score * 0.10 +
        quality_score * 0.05
    )
    
    if log_details:
        print("\n🧮 FINAL CALCULATION:")
        print(f"   ({temporal_score:.1f} × 0.40) + ({frequency_score:.1f} × 0.25) + ({pattern_score:.1f} × 0.20) + ({consistency_score:.1f} × 0.10) + ({quality_score:.1f} × 0.05)")
        print(f"   = {temporal_score * 0.40:.2f} + {frequency_score * 0.25:.2f} + {pattern_score * 0.20:.2f} + {consistency_score * 0.10:.2f} + {quality_score * 0.05:.2f}")
        print(f"   = {final_score:.2f}")
        print(f"\n🎯 FINAL RECENCY SCORE: {final_score:.2f}")
        
        # Score interpretation
        if final_score >= 90:
            interpretation = "🌟 EXCELLENT - Highly recent and reliable"
        elif final_score >= 75:
            interpretation = "✅ GOOD - Recent and trustworthy"
        elif final_score >= 60:
            interpretation = "⚠️ FAIR - Moderately recent"
        elif final_score >= 40:
            interpretation = "🔶 POOR - Old but potentially valid"
        else:
            interpretation = "❌ VERY POOR - Very old or unreliable"
            
        print(f"📊 INTERPRETATION: {interpretation}")
        print("=" * 60)
    
    return final_score

def calculate_temporal_score(row, prefix, current_date, log_details=False):
    """
    Calculate temporal score based on last delivery date
    """
    delivery_date_field = f'{prefix}.lastDeliveryDate'
    
    if delivery_date_field not in row or pd.isna(row[delivery_date_field]):
        if log_details:
            print("⏰ 1. TEMPORAL SCORE (40% weight):")
            print(f"   ❌ No delivery date found in field: {delivery_date_field}")
            print("   📊 Score: 0.0 points")
        return 0
    
    try:
        delivery_date_raw = row[delivery_date_field]
        if log_details:
            print("⏰ 1. TEMPORAL SCORE (40% weight):")
            print(f"   📅 Raw delivery date value: '{delivery_date_raw}' (type: {type(delivery_date_raw)})")
        
        # Try multiple date parsing approaches
        delivery_date = None
        
        # Approach 1: Direct pandas parsing
        try:
            delivery_date = pd.to_datetime(delivery_date_raw)
            if log_details:
                print(f"   ✅ Successfully parsed with pd.to_datetime()")
        except:
            pass
        
        # Approach 2: Handle string dates with specific formats
        if delivery_date is None and isinstance(delivery_date_raw, str):
            try:
                delivery_date = pd.to_datetime(delivery_date_raw, format='%Y-%m-%dT%H:%M:%S.%fZ')
                if log_details:
                    print(f"   ✅ Successfully parsed with ISO format")
            except:
                try:
                    delivery_date = pd.to_datetime(delivery_date_raw, infer_datetime_format=True)
                    if log_details:
                        print(f"   ✅ Successfully parsed with inferred format")
                except:
                    pass
        
        if delivery_date is None:
            if log_details:
                print(f"   ❌ Failed to parse date: '{delivery_date_raw}'")
                print("   📊 Score: 0.0 points")
            return 0
        
        # Handle timezone issues - convert both dates to timezone-naive
        if delivery_date.tz is not None:
            # Convert timezone-aware delivery_date to UTC then remove timezone
            delivery_date = delivery_date.tz_convert('UTC').tz_localize(None)
            if log_details:
                print(f"   🌍 Converted timezone-aware date to UTC naive")
        
        # Ensure current_date is also timezone-naive
        if hasattr(current_date, 'tz') and current_date.tz is not None:
            current_date = current_date.tz_localize(None)
        
        days_diff = (current_date - delivery_date).days
        
        if days_diff <= 7:
            score = 100
            category = "Perfect - Within 7 days"
        elif days_diff <= 90:
            score = 50 + 35 * math.exp(-0.05 * (days_diff - 7))
            category = "Good - Exponential decay (8-90 days)"
        elif days_diff <= 365:
            score = max(5, 20 - 15 * ((days_diff - 90) / 275))
            category = "Fair - Linear decay (91-365 days)"
        else:
            score = 5
            category = "Poor - Over 1 year old"
            
        if log_details:
            print(f"   📅 Parsed delivery date: {delivery_date.strftime('%Y-%m-%d %H:%M:%S')}")
            print(f"   📆 Days ago: {days_diff}")
            print(f"   📈 Category: {category}")
            print(f"   📊 Score: {score:.1f} points")
        
        return score
        
    except Exception as e:
        if log_details:
            print(f"   ❌ Error parsing delivery date: {str(e)}")
            print(f"   📅 Raw value: '{row[delivery_date_field]}'")
            print("   📊 Score: 0.0 points")
        return 0

def calculate_frequency_score(row, prefix, log_details=False):
    """
    Calculate frequency score based on times seen
    """
    times_seen_field = f'{prefix}.timesSeen'
    
    if times_seen_field not in row or pd.isna(row[times_seen_field]):
        times_seen = 0
    else:
        # Handle both int64 and float64 data types
        try:
            times_seen = int(float(row[times_seen_field]))
        except (ValueError, TypeError):
            times_seen = 0
    
    if times_seen == 0:
        score = 0
        category = "No usage data - zero score"
    elif times_seen == 1:
        score = 40
        category = "Single use - potentially outdated"
    elif times_seen <= 3:
        score = 40 + (times_seen - 1) * 20
        category = f"Moderate confidence - {times_seen} uses"
    elif times_seen <= 10:
        score = 80 + (times_seen - 3) * 2.4
        category = f"Regular usage - {times_seen} uses"
    else:
        score = min(100, 97 + (times_seen - 10) * 0.3)
        category = f"High confidence - {times_seen} uses"
    
    if log_details:
        print("\n🔄 2. FREQUENCY SCORE (25% weight):")
        print(f"   🔢 Times seen: {times_seen}")
        print(f"   📈 Category: {category}")
        print(f"   📊 Score: {score:.1f} points")
    
    return score

def calculate_pattern_score(row, address_index, log_details=False):
    """
    Calculate usage pattern score based on address type
    """
    address_types = get_address_types(row, address_index)
    
    type_scores = {
        'logisticsAddress': 90,        # High recency importance - active delivery
        'transportDlAddress': 75,      # Moderate - government registered, changes occasionally  
        'taxAddress': 80,              # High - tax filing addresses change when business moves
        'businessAddress': 85,         # High - business operations, moderate change frequency
        'temporaryAddress': 95,        # Highest - by definition temporary
        'billingAddress': 70,          # Moderate - billing addresses change less frequently
        'permanentAddress': 40         # Low - permanent by definition
    }
    
    if not address_types:
        score = 60
        category = "Unknown type - default score"
        type_display = "None/Unknown"
    else:
        # Return the highest score among all types for this address
        scores = [type_scores.get(addr_type, 60) for addr_type in address_types]
        score = max(scores)
        
        # Find the type that gave the max score
        max_type = None
        for addr_type in address_types:
            if type_scores.get(addr_type, 60) == score:
                max_type = addr_type
                break
        
        category = f"{max_type} - {get_type_explanation(max_type)}"
        type_display = str(address_types)
    
    if log_details:
        print("\n🏠 3. USAGE PATTERN SCORE (20% weight):")
        print(f"   🏷️ Address types: {type_display}")
        print(f"   📈 Category: {category}")
        print(f"   📊 Score: {score:.1f} points")
    
    return score

def get_type_explanation(addr_type):
    """
    Get explanation for address type scoring
    """
    explanations = {
        'temporaryAddress': 'Needs frequent updates',
        'logisticsAddress': 'High recency importance',
        'billingAddress': 'Moderate importance',
        'permanentAddress': 'Stable, less critical',
        'transportDlAddress': 'Government registered'
    }
    return explanations.get(addr_type, 'Unknown type')

def calculate_consistency_score(unique_types_count, log_details=False):
    """
    Calculate consistency score based on number of unique address types
    """
    if unique_types_count == 1:
        score = 85
        category = "Excellent - Single consistent type"
    elif unique_types_count == 2:
        score = 70
        category = "Good - Minor inconsistency"
    elif unique_types_count == 3:
        score = 55
        category = "Fair - Moderate confusion"
    else:
        score = 40
        category = "Poor - High inconsistency"
    
    if log_details:
        print("\n📊 4. CONSISTENCY SCORE (10% weight):")
        print(f"   🔢 Unique address types across all user addresses: {unique_types_count}")
        print(f"   📈 Category: {category}")
        print(f"   📊 Score: {score:.1f} points")
    
    return score

def calculate_quality_score(row, prefix, log_details=False):
    """
    Calculate quality score based on address completeness
    """
    completeness_field = f'{prefix}.completeAddress.addressCompletenessScore'
    
    if completeness_field not in row or pd.isna(row[completeness_field]):
        score = 40
        category = "No completeness data - default low score"
        completeness = "N/A"
    else:
        try:
            completeness = float(row[completeness_field])
        except (ValueError, TypeError):
            completeness = 0.0
        
        if completeness >= 80:
            score = 100
            category = "Excellent completeness"
        elif completeness >= 60:
            score = 85
            category = "Good completeness"
        elif completeness >= 40:
            score = 70
            category = "Fair completeness"
        elif completeness >= 20:
            score = 55
            category = "Poor completeness"
        else:
            score = 40
            category = "Very poor completeness"
    
    if log_details:
        print("\n✅ 5. QUALITY IMPACT SCORE (5% weight):")
        if completeness != "N/A":
            print(f"   📋 Address completeness: {completeness:.2f}%")
        else:
            print(f"   📋 Address completeness: {completeness}")
        print(f"   📈 Category: {category}")
        print(f"   📊 Score: {score:.1f} points")
    
    return score

def analyze_results(df_with_scores):
    """
    Analyze and display the recency score results
    """
    # Find all recency score columns
    score_cols = [col for col in df_with_scores.columns if col.endswith('_recency_score')]
    address_text_cols = [col for col in df_with_scores.columns if col.endswith('_address_text')]
    
    if not score_cols:
        print("No recency scores found!")
        return
    
    print("=== RECENCY SCORE ANALYSIS ===\n")
    
    # Overall statistics
    all_scores = []
    for col in score_cols:
        all_scores.extend(df_with_scores[col].dropna().tolist())
    
    if all_scores:
        print(f"Total addresses scored: {len(all_scores)}")
        print(f"Average recency score: {np.mean(all_scores):.2f}")
        print(f"Score range: {min(all_scores):.2f} - {max(all_scores):.2f}")
        print(f"Standard deviation: {np.std(all_scores):.2f}\n")
        
        # Score distribution
        print("Score Distribution:")
        print(f"Excellent (90-100): {sum(1 for s in all_scores if s >= 90)} addresses")
        print(f"Good (75-89): {sum(1 for s in all_scores if 75 <= s < 90)} addresses")
        print(f"Fair (60-74): {sum(1 for s in all_scores if 60 <= s < 75)} addresses")
        print(f"Poor (40-59): {sum(1 for s in all_scores if 40 <= s < 60)} addresses")
        print(f"Very Poor (0-39): {sum(1 for s in all_scores if s < 40)} addresses")
    
    print(f"\n=== SAMPLE RESULTS ===")
    
    # Show sample results with both scores and addresses
    display_cols = ['name', 'email']
    
    # Add score and address pairs in order
    for i in range(10):  # Check up to Address.9
        score_col = f'Address.{i}_recency_score'
        addr_col = f'Address.{i}_address_text'
        if score_col in df_with_scores.columns:
            display_cols.extend([score_col, addr_col])
    
    available_cols = [col for col in display_cols if col in df_with_scores.columns]
    
    sample_df = df_with_scores[available_cols].head(10)
    
    # Display in a more readable format
    for idx, row in sample_df.iterrows():
        print(f"\n--- {row['name']} ({row['email']}) ---")
        for col in available_cols:
            if col.endswith('_recency_score') and pd.notna(row[col]):
                addr_idx = col.split('.')[1].split('_')[0]
                addr_text_col = f'Address.{addr_idx}_address_text'
                addr_text = row.get(addr_text_col, 'N/A')
                print(f"  Score: {row[col]:.2f} | Address: {str(addr_text)[:80]}...")
        
        if idx >= 4:  # Show only first 5 rows in detail
            break
    
    return df_with_scores[score_cols].describe()

# Main execution function
def run_recency_analysis(file_path):
    """
    Main function to run the complete recency analysis
    """
    try:
        # Load the data
        print("Loading data...")
        df = pd.read_csv(file_path)
        print(f"Loaded {len(df)} rows and {len(df.columns)} columns")
        
        # Check for address columns
        address_cols = [col for col in df.columns if 'Address.' in col and 'completeAddress' in col]
        print(f"Found {len(address_cols)} address columns: {address_cols[:5]}...")  # Show first 5
        
        # Calculate recency scores
        print("\nCalculating recency scores...")
        df_with_scores = calculate_recency_scores(df)
        
        # Analyze results
        stats = analyze_results(df_with_scores)
        
        return df_with_scores, stats
        
    except Exception as e:
        print(f"Error: {str(e)}")
        return None, None

# Usage example:
if __name__ == "__main__":
    # Run the analysis
    file_path = "DCB_AlternateAddress.csv"
    df_result, statistics = run_recency_analysis(file_path)
    
    if df_result is not None:
        print(f"\n=== DETAILED STATISTICS ===")
        print(statistics)
# Out:
# Loading data...
# Loaded 4455 rows and 447 columns
# Found 75 address columns: ['Address.0.completeAddress', 'Address.0.completeAddress.addressCompletenessScore', 'Address.0.completeAddress.inputAddressSimilarityScore', 'Address.1.completeAddress', 'Address.1.completeAddress.addressCompletenessScore']...
#
# Calculating recency scores...
#
# ================================================================================
# 🔍 DETAILED SCORING BREAKDOWN FOR FIRST 3 ADDRESSES
# ================================================================================
#
# 🏠 ADDRESS #1 SCORING BREAKDOWN
# ------------------------------------------------------------
# 👤 User:   mohit (mor27nov@gmail.com)
# 📍 Address: 770/28 bharat colony rohtak near shella by pass chock.,House,Rohtak,Ha...
# 🔢 Address Index: Address.0
# ------------------------------------------------------------
# ⏰ 1. TEMPORAL SCORE (40% weight):
#    📅 Raw delivery date value: '2024-03-02T12:01:20.000Z' (type: <class 'str'>)
#    ✅ Successfully parsed with pd.to_datetime()
#    🌍 Converted timezone-aware date to UTC naive
#    📅 Parsed delivery date: 2024-03-02 12:01:20
#    📆 Days ago: 564
#    📈 Category: Poor - Over 1 year old
#    📊 Score: 5.0 points
#
# 🔄 2. FREQUENCY SCORE (25% weight):
#    🔢 Times seen: 1
#    📈 Category: Single use - potentially outdated
#    📊 Score: 40.0 points
#
# 🏠 3. USAGE PATTERN SCORE (20% weight):
#    🏷️ Address types: ['logisticsAddress']
#    📈 Category: logisticsAddress - High recency importance
#    📊 Score: 90.0 points
#
# 📊 4. CONSISTENCY SCORE (10% weight):
#    🔢 Unique address types across all user addresses: 1
#    📈 Category: Excellent - Single consistent type
#    📊 Score: 85.0 points
#
# ✅ 5. QUALITY IMPACT SCORE (5% weight):
#    📋 Address completeness: 48.94%
#    📈 Category: Fair completeness
#    📊 Score: 70.0 points
#
# 🧮 FINAL CALCULATION:
#    (5.0 × 0.40) + (40.0 × 0.25) + (90.0 × 0.20) + (85.0 × 0.10) + (70.0 × 0.05)
#    = 2.00 + 10.00 + 18.00 + 8.50 + 3.50
#    = 42.00
#
# 🎯 FINAL RECENCY SCORE: 42.00
# 📊 INTERPRETATION: 🔶 POOR - Old but potentially valid
# ============================================================
#
# 🏠 ADDRESS #2 SCORING BREAKDOWN
# ------------------------------------------------------------
# 👤 User:   mohit (mor27nov@gmail.com)
# 📍 Address: Sec 36 om enclave near toll tax makroli rohtak Gohana road,Rohtak,Hary...
# 🔢 Address Index: Address.1
# ------------------------------------------------------------
# ⏰ 1. TEMPORAL SCORE (40% weight):
#    📅 Raw delivery date value: '2025-01-15T16:24:00.000Z' (type: <class 'str'>)
#    ✅ Successfully parsed with pd.to_datetime()
#    🌍 Converted timezone-aware date to UTC naive
#    📅 Parsed delivery date: 2025-01-15 16:24:00
#    📆 Days ago: 244
#    📈 Category: Fair - Linear decay (91-365 days)
#    📊 Score: 11.6 points
#
# 🔄 2. FREQUENCY SCORE (25% weight):
#    🔢 Times seen: 1
#    📈 Category: Single use - potentially outdated
#    📊 Score: 40.0 points
#
# 🏠 3. USAGE PATTERN SCORE (20% weight):
#    🏷️ Address types: ['logisticsAddress']
#    📈 Category: logisticsAddress - High recency importance
#    📊 Score: 90.0 points
#
# 📊 4. CONSISTENCY SCORE (10% weight):
#    🔢 Unique address types across all user addresses: 1
#    📈 Category: Excellent - Single consistent type
#    📊 Score: 85.0 points
#
# ✅ 5. QUALITY IMPACT SCORE (5% weight):
#    📋 Address completeness: 65.96%
#    📈 Category: Good completeness
#    📊 Score: 85.0 points
#
# 🧮 FINAL CALCULATION:
#    (11.6 × 0.40) + (40.0 × 0.25) + (90.0 × 0.20) + (85.0 × 0.10) + (85.0 × 0.05)
#    = 4.64 + 10.00 + 18.00 + 8.50 + 4.25
#    = 45.39
#
# 🎯 FINAL RECENCY SCORE: 45.39
# 📊 INTERPRETATION: 🔶 POOR - Old but potentially valid
# ============================================================
#
# 🏠 ADDRESS #3 SCORING BREAKDOWN
# ------------------------------------------------------------
# 👤 User:   sajid (sajid9350249895@gmail.com)
# 📍 Address: Masjid Hadi Ali Shah,Central Delhi,Delhi,India,110055,DL,IN...
# 🔢 Address Index: Address.0
# ------------------------------------------------------------
# ⏰ 1. TEMPORAL SCORE (40% weight):
#    ❌ No delivery date found in field: Address.0.lastDeliveryDate
#    📊 Score: 0.0 points
#
# 🔄 2. FREQUENCY SCORE (25% weight):
#    🔢 Times seen: 1
#    📈 Category: Single use - potentially outdated
#    📊 Score: 40.0 points
#
# 🏠 3. USAGE PATTERN SCORE (20% weight):
#    🏷️ Address types: ['logisticsAddress']
#    📈 Category: logisticsAddress - High recency importance
#    📊 Score: 90.0 points
#
# 📊 4. CONSISTENCY SCORE (10% weight):
#    🔢 Unique address types across all user addresses: 1
#    📈 Category: Excellent - Single consistent type
#    📊 Score: 85.0 points
#
# ✅ 5. QUALITY IMPACT SCORE (5% weight):
#    📋 Address completeness: 25.53%
#    📈 Category: Poor completeness
#    📊 Score: 55.0 points
#
# 🧮 FINAL CALCULATION:
#    (0.0 × 0.40) + (40.0 × 0.25) + (90.0 × 0.20) + (85.0 × 0.10) + (55.0 × 0.05)
#    = 0.00 + 10.00 + 18.00 + 8.50 + 2.75
#    = 39.25
#
# 🎯 FINAL RECENCY SCORE: 39.25
# 📊 INTERPRETATION: ❌ VERY POOR - Very old or unreliable
# ============================================================
# /var/folders/_3/j4fdj65x1hxdgmd_3jkytp980000gn/T/ipykernel_69602/1723416744.py:510: DtypeWarning: Columns (146,149,162,194,197,200,201,202,203,204,205,207,208,209,210,212,213,216,217,218,219,220,221,223,224,225,226,228,229,232,233,234,235,236,237,239,240,241,242,244,245,248,249,250,251,252,253,255,256,257,258,260,261,264,265,266,267,268,269,271,272,273,274,276,277,280,281,282,283,284,285,287,288,289,290,292,293,296,297,298,299,300,301,303,304,305,308,312,313,314,315,316,317,319,320,321,324,327,328,329,330,331,332,334,335,336,339,342,343,344,345,346,347,349,350,351,354,355,357,358,359,360,361,362,364,365,366,367,369,370,372,373,374,375,376,377,379,380,381,382,384,385,387,388,389,390,391,392,394,395,396,397,399,400,402,403,404,405,406,407,409,410,411,412,414,415,417,418,419,420,421,422,424,425,426,427,429,430,432,433,434,435,436,437,439,440,441,444) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# ================================================================================
# ✅ DETAILED LOGGING COMPLETE
# ================================================================================
#
# === RECENCY SCORE ANALYSIS ===
#
# Total addresses scored: 9435
# Average recency score: 39.83
# Score range: 31.75 - 62.27
# Standard deviation: 4.00
#
# Score Distribution:
# Excellent (90-100): 0 addresses
# Good (75-89): 0 addresses
# Fair (60-74): 12 addresses
# Poor (40-59): 4041 addresses
# Very Poor (0-39): 5382 addresses
#
# === SAMPLE RESULTS ===
#
# --- nan (mor27nov@gmail.com) ---
#   Score: 42.00 | Address: 770/28 bharat colony rohtak near shella by pass chock.,House,Rohtak,Haryana,Indi...
#   Score: 45.39 | Address: Sec 36 om enclave near toll tax makroli rohtak Gohana road,Rohtak,Haryana,India,...
#
# --- nan (sajid9350249895@gmail.com) ---
#   Score: 39.25 | Address: Masjid Hadi Ali Shah,Central Delhi,Delhi,India,110055,DL,IN...
#
# --- nan (vishalkewat9755@gmail.com) ---
#   Score: 39.25 | Address: 10 kaladev,10 kaladev,Kaladev dashera madan,Vidisha,Madhya Pradesh,India,464114,...
#   Score: 39.25 | Address: Vidisha tashsil lateari thana kaladev,Dasehra Medan kaladev,Vidisha,Madhya Prade...
#
# --- nan (nan) ---
#   Score: 46.25 | Address: EASLAND ENCLAVE,BLOCK-5,FLAT-502,FIFTH FLOOR,S.A. ROAD,ELAMKULAM,KADAVANTHRA P.O...
#   Score: 39.75 | Address: CROMA KALAMASSERY NEAR CUSAT METRO STATION METRO P,ILLAR 311 SOUTH KALAMASSERY,E...
#   Score: 40.50 | Address: Easland Enclave,Block-5,Flat No 502,Elamkulam,Kadavanthara,Kadavanthara,Ernakula...
#   Score: 34.00 | Address: 8 924  6 424,KANJIRAKKATTU,THRIKKAKKARA,0...
#
# --- nan (nan) ---
#   Score: 39.25 | Address: Golden City Road,1st cross,Collector office back side,Thanthonimalaik,30/2,Karur...
#
# === DETAILED STATISTICS ===
#        Address.0_recency_score  Address.1_recency_score  \
# count              4455.000000              2175.000000
# mean                 40.398831                39.624547
# std                   4.256226                 3.969808
# min                  33.750000                33.500000
# 25%                  37.000000                36.250000
# 50%                  40.000000                39.250000
# 75%                  42.000000                41.250000
# max                  62.270000                61.730000
#
#        Address.2_recency_score  Address.3_recency_score  \
# count              1121.000000               649.000000
# mean                 39.119045                38.893590
# std                   3.387756                 3.467892
# min                  32.500000                31.750000
# 25%                  37.750000                37.750000
# 50%                  39.250000                39.250000
# 75%                  40.500000                40.000000
# max                  58.350000                56.400000
#
#        Address.4_recency_score  Address.5_recency_score  \
# count               393.000000               250.000000
# mean                 39.180712                39.243360
# std                   3.643508                 3.724193
# min                  31.750000                32.500000
# 25%                  37.750000                37.750000
# 50%                  39.250000                39.250000
# 75%                  40.000000                40.000000
# max                  53.660000                56.100000
#
#        Address.6_recency_score  Address.7_recency_score  \
# count               168.000000               105.000000
# mean                 38.632619                39.283714
# std                   2.747306                 2.961269
# min                  32.500000                32.500000
# 25%                  37.750000                38.250000
# 50%                  39.250000                39.250000
# 75%                  39.437500                40.000000
# max                  50.750000                55.480000
#
#        Address.8_recency_score  Address.9_recency_score
# count                69.000000                50.000000
# mean                 38.930870                39.936800
# std                   3.049752                 3.314686
# min                  33.250000                33.250000
# 25%                  37.750000                38.687500
# 50%                  39.250000                39.250000
# 75%                  40.000000                40.000000
# max                  50.750000                51.950000

# %%
file_path = "DCB_AlternateAddress.csv"

df_with_scores, statistics = run_recency_analysis(file_path)

if df_with_scores is not None:
    
    print("\n=== DETAILED BREAKDOWN FOR FIRST 3 ROWS ===")
    
    score_cols = [col for col in df_with_scores.columns if col.endswith('_recency_score')]
    
    for idx in range(min(3, len(df_with_scores))):
        row = df_with_scores.iloc[idx]
        print(f"\nRow {idx + 1} - {row.get('name', 'Unknown')} ({row.get('email', 'No email')}):")
        
        for score_col in score_cols:
            if pd.notna(row[score_col]):
                addr_idx = score_col.split('.')[1].split('_')[0]
                
                # Get the address text from new column
                addr_text_col = f'Address.{addr_idx}_address_text'
                address_text = row.get(addr_text_col, 'N/A')
                
                delivery_date = row.get(f'Address.{addr_idx}.lastDeliveryDate', 'No date')
                times_seen = row.get(f'Address.{addr_idx}.timesSeen', 0)
                addr_type = row.get(f'Address.{addr_idx}.addressType', 'Unknown')
                
                print(f"  {score_col}: {row[score_col]:.2f}")
                print(f"    Address: {str(address_text)[:80]}...")
                print(f"    Last delivery: {delivery_date}")
                print(f"    Times seen: {times_seen}")
                print(f"    Type: {addr_type}")
    
    print("\n=== CLEAN SUMMARY TABLE ===")
    summary_data = []
    
    for idx, row in df_with_scores.iterrows():
        base_info = {
            'Row': idx + 1,
            'Name': row.get('name', 'Unknown'),
            'Email': row.get('email', 'No email')
        }
        
        has_addresses = False
        for score_col in score_cols:
            if pd.notna(row[score_col]):
                has_addresses = True
                addr_idx = score_col.split('.')[1].split('_')[0]
                addr_text_col = f'Address.{addr_idx}_address_text'
                
                row_data = base_info.copy()
                row_data.update({
                    'Address_Index': f'Address.{addr_idx}',
                    'Recency_Score': row[score_col],
                    'Address_Text': str(row.get(addr_text_col, 'N/A'))[:60] + '...',
                    'Last_Delivery': row.get(f'Address.{addr_idx}.lastDeliveryDate', 'No date'),
                    'Times_Seen': row.get(f'Address.{addr_idx}.timesSeen', 0)
                })
                summary_data.append(row_data)
        
        if not has_addresses:
            summary_data.append(base_info)
    
    summary_df = pd.DataFrame(summary_data)
    print(summary_df.head(20).to_string(index=False))
    
    # Save complete results to CSV
    output_file = "DCB_AlternateAddress_with_recency_scores.csv"
    df_with_scores.to_csv(output_file, index=False)
    print(f"\n✅ Complete results saved to: {output_file}")
    
    # Create and save clean final dataframe with only essential columns
    essential_cols = ['email']
    
    # Add all recency score and address text columns
    score_cols = [col for col in df_with_scores.columns if col.endswith('_recency_score')]
    address_cols = [col for col in df_with_scores.columns if col.endswith('_address_text')]
    
    # Combine in pairs (score, address) for each address index
    for i in range(10):  # Check up to Address.9
        score_col = f'Address.{i}_recency_score'
        addr_col = f'Address.{i}_address_text'
        if score_col in df_with_scores.columns:
            essential_cols.extend([score_col, addr_col])
    
    # Create clean dataframe
    df_clean = df_with_scores[essential_cols].copy()
    
    # Save clean version
    clean_output_file = "DCB_Recency_Scores_FINAL.csv"
    df_clean.to_csv(clean_output_file, index=False)
    print(f"✅ Clean final dataframe saved to: {clean_output_file}")
    
    # Show preview of clean dataframe
    print(f"\n=== CLEAN FINAL DATAFRAME PREVIEW ===")
    print(f"Columns: {list(df_clean.columns)}")
    print(f"Shape: {df_clean.shape}")
    print("\nFirst 5 rows:")
    for idx, row in df_clean.head().iterrows():
        print(f"\nRow {idx + 1}: {row['email']}")
        for col in df_clean.columns:
            if col.endswith('_recency_score') and pd.notna(row[col]):
                addr_idx = col.split('.')[1].split('_')[0]
                addr_col = f'Address.{addr_idx}_address_text'
                print(f"  Score: {row[col]:.2f} | Address: {str(row.get(addr_col, 'N/A'))[:50]}...")
    
    # Show all new columns created
    print(f"\n=== NEW COLUMNS CREATED ===")
    new_cols = [col for col in df_with_scores.columns if '_recency_score' in col or '_address_text' in col]
    
    for col in sorted(new_cols):
        if col.endswith('_recency_score'):
            non_null_count = df_with_scores[col].count()
            avg_score = df_with_scores[col].mean() if non_null_count > 0 else 0
            print(f"{col}: {non_null_count} addresses, avg score: {avg_score:.2f}")
        elif col.endswith('_address_text'):
            non_null_count = df_with_scores[col].count()
            print(f"{col}: {non_null_count} address texts")

else:
    print("❌ Analysis failed. Please check your CSV file path and format.")
# Out:
# Loading data...
# Loaded 4455 rows and 447 columns
# Found 75 address columns: ['Address.0.completeAddress', 'Address.0.completeAddress.addressCompletenessScore', 'Address.0.completeAddress.inputAddressSimilarityScore', 'Address.1.completeAddress', 'Address.1.completeAddress.addressCompletenessScore']...
#
# Calculating recency scores...
# /var/folders/_3/j4fdj65x1hxdgmd_3jkytp980000gn/T/ipykernel_69602/510496620.py:306: DtypeWarning: Columns (146,149,162,194,197,200,201,202,203,204,205,207,208,209,210,212,213,216,217,218,219,220,221,223,224,225,226,228,229,232,233,234,235,236,237,239,240,241,242,244,245,248,249,250,251,252,253,255,256,257,258,260,261,264,265,266,267,268,269,271,272,273,274,276,277,280,281,282,283,284,285,287,288,289,290,292,293,296,297,298,299,300,301,303,304,305,308,312,313,314,315,316,317,319,320,321,324,327,328,329,330,331,332,334,335,336,339,342,343,344,345,346,347,349,350,351,354,355,357,358,359,360,361,362,364,365,366,367,369,370,372,373,374,375,376,377,379,380,381,382,384,385,387,388,389,390,391,392,394,395,396,397,399,400,402,403,404,405,406,407,409,410,411,412,414,415,417,418,419,420,421,422,424,425,426,427,429,430,432,433,434,435,436,437,439,440,441,444) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# === RECENCY SCORE ANALYSIS ===
#
# Total addresses scored: 9435
# Average recency score: 38.50
# Score range: 28.75 - 61.27
# Standard deviation: 4.38
#
# Score Distribution:
# Excellent (90-100): 0 addresses
# Good (75-89): 0 addresses
# Fair (60-74): 6 addresses
# Poor (40-59): 3046 addresses
# Very Poor (0-39): 6383 addresses
#
# === SAMPLE RESULTS ===
#
# --- nan (mor27nov@gmail.com) ---
#   Score: 41.00 | Address: 770/28 bharat colony rohtak near shella by pass chock.,House,Rohtak,Haryana,Indi...
#   Score: 44.39 | Address: Sec 36 om enclave near toll tax makroli rohtak Gohana road,Rohtak,Haryana,India,...
#
# --- nan (sajid9350249895@gmail.com) ---
#   Score: 38.25 | Address: Masjid Hadi Ali Shah,Central Delhi,Delhi,India,110055,DL,IN...
#
# --- nan (vishalkewat9755@gmail.com) ---
#   Score: 38.25 | Address: 10 kaladev,10 kaladev,Kaladev dashera madan,Vidisha,Madhya Pradesh,India,464114,...
#   Score: 38.25 | Address: Vidisha tashsil lateari thana kaladev,Dasehra Medan kaladev,Vidisha,Madhya Prade...
#
# --- nan (nan) ---
#   Score: 45.25 | Address: EASLAND ENCLAVE,BLOCK-5,FLAT-502,FIFTH FLOOR,S.A. ROAD,ELAMKULAM,KADAVANTHRA P.O...
#   Score: 38.75 | Address: CROMA KALAMASSERY NEAR CUSAT METRO STATION METRO P,ILLAR 311 SOUTH KALAMASSERY,E...
#   Score: 39.50 | Address: Easland Enclave,Block-5,Flat No 502,Elamkulam,Kadavanthara,Kadavanthara,Ernakula...
#   Score: 33.00 | Address: 8 924  6 424,KANJIRAKKATTU,THRIKKAKKARA,0...
#
# --- nan (nan) ---
#   Score: 38.25 | Address: Golden City Road,1st cross,Collector office back side,Thanthonimalaik,30/2,Karur...
#
# === DETAILED BREAKDOWN FOR FIRST 3 ROWS ===
#
# Row 1 - nan (mor27nov@gmail.com):
#   Address.0_recency_score: 41.00
#     Address: 770/28 bharat colony rohtak near shella by pass chock.,House,Rohtak,Haryana,Indi...
#     Last delivery: 2024-03-02T12:01:20.000Z
#     Times seen: 1
#     Type: ['logisticsAddress']
#   Address.1_recency_score: 44.39
#     Address: Sec 36 om enclave near toll tax makroli rohtak Gohana road,Rohtak,Haryana,India,...
#     Last delivery: 2025-01-15T16:24:00.000Z
#     Times seen: 1.0
#     Type: ['logisticsAddress']
#
# Row 2 - nan (sajid9350249895@gmail.com):
#   Address.0_recency_score: 38.25
#     Address: Masjid Hadi Ali Shah,Central Delhi,Delhi,India,110055,DL,IN...
#     Last delivery: nan
#     Times seen: 1
#     Type: ['logisticsAddress']
#
# Row 3 - nan (vishalkewat9755@gmail.com):
#   Address.0_recency_score: 38.25
#     Address: 10 kaladev,10 kaladev,Kaladev dashera madan,Vidisha,Madhya Pradesh,India,464114,...
#     Last delivery: nan
#     Times seen: 1
#     Type: ['logisticsAddress']
#   Address.1_recency_score: 38.25
#     Address: Vidisha tashsil lateari thana kaladev,Dasehra Medan kaladev,Vidisha,Madhya Prade...
#     Last delivery: nan
#     Times seen: 1.0
#     Type: ['logisticsAddress']
#
# === CLEAN SUMMARY TABLE ===
#  Row  Name                         Email Address_Index  Recency_Score                                                    Address_Text            Last_Delivery  Times_Seen
#    1   NaN            mor27nov@gmail.com     Address.0          41.00 770/28 bharat colony rohtak near shella by pass chock.,House... 2024-03-02T12:01:20.000Z         1.0
#    1   NaN            mor27nov@gmail.com     Address.1          44.39 Sec 36 om enclave near toll tax makroli rohtak Gohana road,R... 2025-01-15T16:24:00.000Z         1.0
#    2   NaN     sajid9350249895@gmail.com     Address.0          38.25  Masjid Hadi Ali Shah,Central Delhi,Delhi,India,110055,DL,IN...                      NaN         1.0
#    3   NaN     vishalkewat9755@gmail.com     Address.0          38.25 10 kaladev,10 kaladev,Kaladev dashera madan,Vidisha,Madhya P...                      NaN         1.0
#    3   NaN     vishalkewat9755@gmail.com     Address.1          38.25 Vidisha tashsil lateari thana kaladev,Dasehra Medan kaladev,...                      NaN         1.0
#    4   NaN                           NaN     Address.0          45.25 EASLAND ENCLAVE,BLOCK-5,FLAT-502,FIFTH FLOOR,S.A. ROAD,ELAMK... 2024-05-22T16:29:52.000Z         2.0
#    4   NaN                           NaN     Address.1          38.75 CROMA KALAMASSERY NEAR CUSAT METRO STATION METRO P,ILLAR 311... 2023-08-21T11:43:00.000Z         1.0
#    4   NaN                           NaN     Address.2          39.50 Easland Enclave,Block-5,Flat No 502,Elamkulam,Kadavanthara,K... 2024-05-22T16:29:52.000Z         1.0
#    4   NaN                           NaN     Address.3          33.00                    8 924  6 424,KANJIRAKKATTU,THRIKKAKKARA,0...                      NaN         1.0
#    5   NaN                           NaN     Address.0          38.25 Golden City Road,1st cross,Collector office back side,Thanth...                      NaN         1.0
#    6   NaN                           NaN     Address.0          36.00 75/77 BABULA TANK RD SHERIAR BAUG,1ST FLR FLAT 07 C BLOCK,MU...                      NaN         1.0
#    7   NaN aakanksha.chauhan@dcbbank.com     Address.0          43.49 C217 actual street number is 8 majlis park azadpur Majlis Pa... 2025-01-08T18:17:54.000Z         1.0
#    7   NaN aakanksha.chauhan@dcbbank.com     Address.1          38.25 C-217 Street Number 8  Majlis Park Azadpur .,North West Delh...                      NaN         1.0
#    7   NaN aakanksha.chauhan@dcbbank.com     Address.2          39.00 C-217/8 Majlis Park Azadpur,North West Delhi,Delhi,India,110...                      NaN         1.0
#    8   NaN                           NaN     Address.0          39.00 A-86,4th floor,Ashok Vihar,Phase- 3,4th floor,North West Del...                      NaN         1.0
#    9   NaN                           NaN     Address.0          34.50                    HN 21,DHANA(138),PUNAHANA,MEWAT,HR,122508...                      NaN         1.0
#   10   NaN                           NaN     Address.0          33.25         AMEE,RAIYA ROAD,SUBHASH NAGAR,RAJKOT.,GUJARAT,360001...                      NaN         1.0
#   11   NaN               kabexp@vsnl.com     Address.0          40.88 1801,tower 1,terra,planet godrej,Mahalaxmi,kk marg. Near Jac... 2025-01-27T11:26:13.000Z         1.0
#   11   NaN               kabexp@vsnl.com     Address.1          35.25 1801,tower 1,terra,planet godrej,Mahalaxmi,kk marg. Nea r Ja...                      NaN         1.0
#   11   NaN               kabexp@vsnl.com     Address.2          36.00 1801  tower 1  terra  planet godrej  Mahalaxmi  kk marg. Nea...                      NaN         1.0
#
# ✅ Complete results saved to: DCB_AlternateAddress_with_recency_scores.csv
# ✅ Clean final dataframe saved to: DCB_Recency_Scores_FINAL.csv
#
# === CLEAN FINAL DATAFRAME PREVIEW ===
# Columns: ['email', 'Address.0_recency_score', 'Address.0_address_text', 'Address.1_recency_score', 'Address.1_address_text', 'Address.2_recency_score', 'Address.2_address_text', 'Address.3_recency_score', 'Address.3_address_text', 'Address.4_recency_score', 'Address.4_address_text', 'Address.5_recency_score', 'Address.5_address_text', 'Address.6_recency_score', 'Address.6_address_text', 'Address.7_recency_score', 'Address.7_address_text', 'Address.8_recency_score', 'Address.8_address_text', 'Address.9_recency_score', 'Address.9_address_text']
# Shape: (4455, 21)
#
# First 5 rows:
#
# Row 1: mor27nov@gmail.com
#   Score: 41.00 | Address: 770/28 bharat colony rohtak near shella by pass ch...
#   Score: 44.39 | Address: Sec 36 om enclave near toll tax makroli rohtak Goh...
#
# Row 2: sajid9350249895@gmail.com
#   Score: 38.25 | Address: Masjid Hadi Ali Shah,Central Delhi,Delhi,India,110...
#
# Row 3: vishalkewat9755@gmail.com
#   Score: 38.25 | Address: 10 kaladev,10 kaladev,Kaladev dashera madan,Vidish...
#   Score: 38.25 | Address: Vidisha tashsil lateari thana kaladev,Dasehra Meda...
#
# Row 4: nan
#   Score: 45.25 | Address: EASLAND ENCLAVE,BLOCK-5,FLAT-502,FIFTH FLOOR,S.A. ...
#   Score: 38.75 | Address: CROMA KALAMASSERY NEAR CUSAT METRO STATION METRO P...
#   Score: 39.50 | Address: Easland Enclave,Block-5,Flat No 502,Elamkulam,Kada...
#   Score: 33.00 | Address: 8 924  6 424,KANJIRAKKATTU,THRIKKAKKARA,0...
#
# Row 5: nan
#   Score: 38.25 | Address: Golden City Road,1st cross,Collector office back s...
#
# === NEW COLUMNS CREATED ===
# Address.0_address_text: 4455 address texts
# Address.0_recency_score: 4455 addresses, avg score: 38.99
# Address.1_address_text: 2175 address texts
# Address.1_recency_score: 2175 addresses, avg score: 38.36
# Address.2_address_text: 1121 address texts
# Address.2_recency_score: 1121 addresses, avg score: 37.90
# Address.3_address_text: 649 address texts
# Address.3_recency_score: 649 addresses, avg score: 37.67
# Address.4_address_text: 393 address texts
# Address.4_recency_score: 393 addresses, avg score: 37.90
# Address.5_address_text: 250 address texts
# Address.5_recency_score: 250 addresses, avg score: 37.99
# Address.6_address_text: 168 address texts
# Address.6_recency_score: 168 addresses, avg score: 37.39
# Address.7_address_text: 105 address texts
# Address.7_recency_score: 105 addresses, avg score: 38.16
# Address.8_address_text: 69 address texts
# Address.8_recency_score: 69 addresses, avg score: 37.53
# Address.9_address_text: 50 address texts
# Address.9_recency_score: 50 addresses, avg score: 38.74

# %%
df1=pd.read_csv('DCB_AlternateAddress.csv')
# Out:
# /var/folders/_3/j4fdj65x1hxdgmd_3jkytp980000gn/T/ipykernel_69602/3646607599.py:1: DtypeWarning: Columns (146,149,162,194,197,200,201,202,203,204,205,207,208,209,210,212,213,216,217,218,219,220,221,223,224,225,226,228,229,232,233,234,235,236,237,239,240,241,242,244,245,248,249,250,251,252,253,255,256,257,258,260,261,264,265,266,267,268,269,271,272,273,274,276,277,280,281,282,283,284,285,287,288,289,290,292,293,296,297,298,299,300,301,303,304,305,308,312,313,314,315,316,317,319,320,321,324,327,328,329,330,331,332,334,335,336,339,342,343,344,345,346,347,349,350,351,354,355,357,358,359,360,361,362,364,365,366,367,369,370,372,373,374,375,376,377,379,380,381,382,384,385,387,388,389,390,391,392,394,395,396,397,399,400,402,403,404,405,406,407,409,410,411,412,414,415,417,418,419,420,421,422,424,425,426,427,429,430,432,433,434,435,436,437,439,440,441,444) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1=pd.read_csv('DCB_AlternateAddress.csv')

# %%
df1
# Out:
#                                                 Address  dob  \
# 0                                                   NaN  NaN
# 1                                                   NaN  NaN
# 2                                                   NaN  NaN
# 3     EASLAND ENCLAVE BLOCK 5FLAT NO 502 ELAMKULAM K...  NaN
# 4                                                   NaN  NaN
# ...                                                 ...  ...
# 4450                                                NaN  NaN
# 4451                                                NaN  NaN
# 4452  NOORANI BLDG 3RD FLR B WING FLAT NO 134THAKUPA...  NaN
# 4453  VASANT OASIS/14/1406, MAKWANA ROADSEVEN HILLS ...  NaN
# 4454                                                NaN  NaN
#
#                           email  name       nameoftheindividual  pan  \
# 0            mor27nov@gmail.com   NaN                     mohit  NaN
# 1     sajid9350249895@gmail.com   NaN                     sajid  NaN
# 2     vishalkewat9755@gmail.com   NaN                    vishal  NaN
# 3                           NaN   NaN             a n abhimanyu  NaN
# 4                           NaN   NaN                  a naveen  NaN
# ...                         ...   ...                       ...  ...
# 4450                        NaN   NaN           zulaikha naaz j  NaN
# 4451        info@opal-stone.com   NaN      zulfikar kasam momin  NaN
# 4452    zulfikar.kerai@yahoo.in   NaN    zulfikar shabbir kerai  NaN
# 4453  z.dahodwala@microinks.com   NaN  zuzer akberali dahodwala  NaN
# 4454        zuzer_j@hotmail.com   NaN     zuzer bakir jawadwala  NaN
#
#        pannumber   phoneNumber  \
# 0     BBHPM7213G  919854005000
# 1     NVHPS1509D  919350249895
# 2     CIKPV3762Q  918519095564
# 3     BJYPA8676E  917012405231
# 4     BUWPN0014N  919080872911
# ...          ...           ...
# 4450  AAIPZ7235Q  919940588865
# 4451  AAHPM4235E  919137590133
# 4452  AYXPK8406D  919892457147
# 4453  AAHPD0277F  919820031768
# 4454  ADIPJ8072C  919820349498
#
#                                  Address.0.addressLine1  \
# 0     770/28 bharat colony rohtak near shella by pas...
# 1                                  Masjid Hadi Ali Shah
# 2                                            10 kaladev
# 3                                       EASLAND ENCLAVE
# 4                                      Golden City Road
# ...                                                 ...
# 4450  owners court 6th floor 6E Montieth lane egmore...
# 4451                                                101
# 4452                       Poonam Residency Bldg no 104
# 4453                           Zuzer Akberali Dahodwala
# 4454                                 301 Sarkar tower 3
#
#                                  Address.0.addressLine2  ...  \
# 0               House,Rohtak,Haryana,India,124001,HR,IN  ...
# 1                Central Delhi,Delhi,India,110055,DL,IN  ...
# 2     10 kaladev,Kaladev dashera madan,Vidisha,Madhy...  ...
# 3     BLOCK-5,FLAT-502,FIFTH FLOOR,S.A. ROAD,ELAMKUL...  ...
# 4     1st cross,Collector office back side,Thanthoni...  ...
# ...                                                 ...  ...
# 4450              Chennai,Tamil Nadu,India,600008,TN,IN  ...
# 4451  LOVELY HOME SOCIETY VAISHALI NAGAR NEAR RUBY H...  ...
# 4452  6th floor Room no 603 Shanti park,Near Balaji ...  ...
# 4453  Vasant Oasis/14/1406,Seven Hills Hospital,Mumb...  ...
# 4454  10 Nesbit road opp ST Marys Icse School Mazgao...  ...
#
#      Address.27.completeAddress  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 4450                        NaN
# 4451                        NaN
# 4452                        NaN
# 4453                        NaN
# 4454                        NaN
#
#      Address.27.completeAddress.addressCompletenessScore Address.27.country  \
# 0                                                   NaN                 NaN
# 1                                                   NaN                 NaN
# 2                                                   NaN                 NaN
# 3                                                   NaN                 NaN
# 4                                                   NaN                 NaN
# ...                                                 ...                 ...
# 4450                                                NaN                 NaN
# 4451                                                NaN                 NaN
# 4452                                                NaN                 NaN
# 4453                                                NaN                 NaN
# 4454                                                NaN                 NaN
#
#      Address.27.countryCode  Address.27.email Address.27.lastDeliveryDate  \
# 0                       NaN               NaN                         NaN
# 1                       NaN               NaN                         NaN
# 2                       NaN               NaN                         NaN
# 3                       NaN               NaN                         NaN
# 4                       NaN               NaN                         NaN
# ...                     ...               ...                         ...
# 4450                    NaN               NaN                         NaN
# 4451                    NaN               NaN                         NaN
# 4452                    NaN               NaN                         NaN
# 4453                    NaN               NaN                         NaN
# 4454                    NaN               NaN                         NaN
#
#      Address.27.pinCode Address.27.state Address.27.stateCode  \
# 0                   NaN              NaN                  NaN
# 1                   NaN              NaN                  NaN
# 2                   NaN              NaN                  NaN
# 3                   NaN              NaN                  NaN
# 4                   NaN              NaN                  NaN
# ...                 ...              ...                  ...
# 4450                NaN              NaN                  NaN
# 4451                NaN              NaN                  NaN
# 4452                NaN              NaN                  NaN
# 4453                NaN              NaN                  NaN
# 4454                NaN              NaN                  NaN
#
#       Address.27.timesSeen
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 4450                   NaN
# 4451                   NaN
# 4452                   NaN
# 4453                   NaN
# 4454                   NaN
#
# [4455 rows x 447 columns]

# %%
pd.set_option('display.max_rows', None)  
print(df1.dtypes)
# Out:
# Address                                                    object
# dob                                                       float64
# email                                                      object
# name                                                      float64
# nameoftheindividual                                        object
# pan                                                       float64
# pannumber                                                  object
# phoneNumber                                                 int64
# Address.0.addressLine1                                     object
# Address.0.addressLine2                                     object
# Address.0.addressType                                      object
# Address.0.associatedName                                   object
# Address.0.city                                             object
# Address.0.completeAddress                                  object
# Address.0.completeAddress.addressCompletenessScore        float64
# Address.0.country                                          object
# Address.0.countryCode                                      object
# Address.0.email                                            object
# Address.0.lastDeliveryDate                                 object
# Address.0.pinCode                                         float64
# Address.0.state                                            object
# Address.0.stateCode                                        object
# Address.0.timesSeen                                         int64
# Address.0.completeAddress.inputAddressSimilarityScore     float64
# Address.1.addressLine1                                     object
# Address.1.addressLine2                                     object
# Address.1.addressType                                      object
# Address.1.associatedName                                   object
# Address.1.city                                             object
# Address.1.completeAddress                                  object
# Address.1.completeAddress.addressCompletenessScore        float64
# Address.1.country                                          object
# Address.1.countryCode                                      object
# Address.1.email                                            object
# Address.1.lastDeliveryDate                                 object
# Address.1.pinCode                                         float64
# Address.1.state                                            object
# Address.1.stateCode                                        object
# Address.1.timesSeen                                       float64
# Address.1.completeAddress.inputAddressSimilarityScore     float64
# Address.2.addressLine1                                     object
# Address.2.addressLine2                                     object
# Address.2.addressType                                      object
# Address.2.associatedName                                   object
# Address.2.city                                             object
# Address.2.completeAddress                                  object
# Address.2.completeAddress.addressCompletenessScore        float64
# Address.2.completeAddress.inputAddressSimilarityScore     float64
# Address.2.country                                          object
# Address.2.countryCode                                      object
# Address.2.email                                            object
# Address.2.lastDeliveryDate                                 object
# Address.2.pinCode                                         float64
# Address.2.state                                            object
# Address.2.stateCode                                        object
# Address.2.timesSeen                                       float64
# Address.3.addressLine1                                     object
# Address.3.addressLine2                                     object
# Address.3.addressType                                      object
# Address.3.associatedName                                   object
# Address.3.city                                             object
# Address.3.completeAddress                                  object
# Address.3.completeAddress.addressCompletenessScore        float64
# Address.3.completeAddress.inputAddressSimilarityScore     float64
# Address.3.country                                          object
# Address.3.countryCode                                      object
# Address.3.email                                            object
# Address.3.lastDeliveryDate                                 object
# Address.3.pinCode                                         float64
# Address.3.state                                            object
# Address.3.stateCode                                        object
# Address.3.timesSeen                                       float64
# Address.4.addressLine1                                     object
# Address.4.addressLine2                                     object
# Address.4.addressType                                      object
# Address.4.associatedName                                   object
# Address.4.city                                             object
# Address.4.completeAddress                                  object
# Address.4.completeAddress.addressCompletenessScore        float64
# Address.4.country                                          object
# Address.4.countryCode                                      object
# Address.4.email                                            object
# Address.4.lastDeliveryDate                                 object
# Address.4.pinCode                                         float64
# Address.4.state                                            object
# Address.4.stateCode                                        object
# Address.4.timesSeen                                       float64
# Address.4.completeAddress.inputAddressSimilarityScore     float64
# Address.5.addressLine1                                     object
# Address.5.addressLine2                                     object
# Address.5.addressType                                      object
# Address.5.associatedName                                   object
# Address.5.city                                             object
# Address.5.completeAddress                                  object
# Address.5.completeAddress.addressCompletenessScore        float64
# Address.5.country                                          object
# Address.5.countryCode                                      object
# Address.5.email                                            object
# Address.5.lastDeliveryDate                                 object
# Address.5.pinCode                                         float64
# Address.5.state                                            object
# Address.5.stateCode                                        object
# Address.5.timesSeen                                       float64
# Address.5.completeAddress.inputAddressSimilarityScore     float64
# Address.6.addressLine1                                     object
# Address.6.addressLine2                                     object
# Address.6.addressType                                      object
# Address.6.associatedName                                   object
# Address.6.city                                             object
# Address.6.completeAddress                                  object
# Address.6.completeAddress.addressCompletenessScore        float64
# Address.6.country                                          object
# Address.6.countryCode                                      object
# Address.6.email                                            object
# Address.6.lastDeliveryDate                                 object
# Address.6.pinCode                                         float64
# Address.6.state                                            object
# Address.6.stateCode                                        object
# Address.6.timesSeen                                       float64
# Address.6.completeAddress.inputAddressSimilarityScore     float64
# Address.7.addressLine1                                     object
# Address.7.addressLine2                                     object
# Address.7.addressType                                      object
# Address.7.associatedName                                   object
# Address.7.city                                             object
# Address.7.completeAddress                                  object
# Address.7.completeAddress.addressCompletenessScore        float64
# Address.7.country                                          object
# Address.7.countryCode                                      object
# Address.7.email                                            object
# Address.7.lastDeliveryDate                                 object
# Address.7.pinCode                                         float64
# Address.7.state                                            object
# Address.7.stateCode                                        object
# Address.7.timesSeen                                       float64
# Address.7.completeAddress.inputAddressSimilarityScore     float64
# Address.8.addressLine1                                     object
# Address.8.addressLine2                                     object
# Address.8.addressType                                      object
# Address.8.associatedName                                   object
# Address.8.city                                             object
# Address.8.completeAddress                                  object
# Address.8.completeAddress.addressCompletenessScore        float64
# Address.8.country                                          object
# Address.8.countryCode                                      object
# Address.8.email                                            object
# Address.8.lastDeliveryDate                                 object
# Address.8.pinCode                                         float64
# Address.8.state                                            object
# Address.8.stateCode                                        object
# Address.8.timesSeen                                       float64
# Address.8.completeAddress.inputAddressSimilarityScore     float64
# Address.9.addressLine1                                     object
# Address.9.addressLine2                                     object
# Address.9.addressType                                      object
# Address.9.associatedName                                   object
# Address.9.city                                             object
# Address.9.completeAddress                                  object
# Address.9.completeAddress.addressCompletenessScore        float64
# Address.9.country                                          object
# Address.9.countryCode                                      object
# Address.9.email                                            object
# Address.9.lastDeliveryDate                                 object
# Address.9.pinCode                                         float64
# Address.9.state                                            object
# Address.9.stateCode                                        object
# Address.9.timesSeen                                       float64
# Address.9.completeAddress.inputAddressSimilarityScore     float64
# Address.10.addressLine1                                    object
# Address.10.addressLine2                                    object
# Address.10.addressType                                     object
# Address.10.associatedName                                  object
# Address.10.city                                            object
# Address.10.completeAddress                                 object
# Address.10.completeAddress.addressCompletenessScore       float64
# Address.10.country                                         object
# Address.10.countryCode                                     object
# Address.10.email                                           object
# Address.10.lastDeliveryDate                                object
# Address.10.pinCode                                        float64
# Address.10.state                                           object
# Address.10.stateCode                                       object
# Address.10.timesSeen                                      float64
# Address.10.completeAddress.inputAddressSimilarityScore    float64
# Address.11.addressLine1                                    object
# Address.11.addressLine2                                    object
# Address.11.addressType                                     object
# Address.11.associatedName                                  object
# Address.11.city                                            object
# Address.11.completeAddress                                 object
# Address.11.completeAddress.addressCompletenessScore       float64
# Address.11.country                                         object
# Address.11.countryCode                                     object
# Address.11.email                                           object
# Address.11.lastDeliveryDate                                object
# Address.11.pinCode                                        float64
# Address.11.state                                           object
# Address.11.stateCode                                       object
# Address.11.timesSeen                                      float64
# Address.11.completeAddress.inputAddressSimilarityScore    float64
# Address.12.addressLine1                                    object
# Address.12.addressLine2                                    object
# Address.12.addressType                                     object
# Address.12.associatedName                                  object
# Address.12.city                                            object
# Address.12.completeAddress                                 object
# Address.12.completeAddress.addressCompletenessScore       float64
# Address.12.country                                         object
# Address.12.countryCode                                     object
# Address.12.email                                           object
# Address.12.lastDeliveryDate                                object
# Address.12.pinCode                                        float64
# Address.12.state                                           object
# Address.12.stateCode                                       object
# Address.12.timesSeen                                      float64
# Address.12.completeAddress.inputAddressSimilarityScore    float64
# Address.13.addressLine1                                    object
# Address.13.addressLine2                                    object
# Address.13.addressType                                     object
# Address.13.associatedName                                  object
# Address.13.city                                            object
# Address.13.completeAddress                                 object
# Address.13.completeAddress.addressCompletenessScore       float64
# Address.13.country                                         object
# Address.13.countryCode                                     object
# Address.13.email                                           object
# Address.13.lastDeliveryDate                                object
# Address.13.pinCode                                        float64
# Address.13.state                                           object
# Address.13.stateCode                                       object
# Address.13.timesSeen                                      float64
# Address.13.completeAddress.inputAddressSimilarityScore    float64
# Address.14.addressLine1                                    object
# Address.14.addressLine2                                    object
# Address.14.addressType                                     object
# Address.14.associatedName                                  object
# Address.14.city                                            object
# Address.14.completeAddress                                 object
# Address.14.completeAddress.addressCompletenessScore       float64
# Address.14.country                                         object
# Address.14.countryCode                                     object
# Address.14.email                                           object
# Address.14.lastDeliveryDate                                object
# Address.14.pinCode                                        float64
# Address.14.state                                           object
# Address.14.stateCode                                       object
# Address.14.timesSeen                                      float64
# Address.14.completeAddress.inputAddressSimilarityScore    float64
# Address.15.addressLine1                                    object
# Address.15.addressLine2                                    object
# Address.15.addressType                                     object
# Address.15.associatedName                                  object
# Address.15.city                                            object
# Address.15.completeAddress                                 object
# Address.15.completeAddress.addressCompletenessScore       float64
# Address.15.country                                         object
# Address.15.countryCode                                     object
# Address.15.email                                           object
# Address.15.lastDeliveryDate                                object
# Address.15.pinCode                                        float64
# Address.15.state                                           object
# Address.15.stateCode                                       object
# Address.15.timesSeen                                      float64
# Address.15.completeAddress.inputAddressSimilarityScore    float64
# Address.16.addressLine1                                    object
# Address.16.addressLine2                                    object
# Address.16.addressType                                     object
# Address.16.associatedName                                  object
# Address.16.city                                            object
# Address.16.completeAddress                                 object
# Address.16.completeAddress.addressCompletenessScore       float64
# Address.16.country                                         object
# Address.16.countryCode                                     object
# Address.16.email                                           object
# Address.16.lastDeliveryDate                                object
# Address.16.pinCode                                        float64
# Address.16.state                                           object
# Address.16.stateCode                                       object
# Address.16.timesSeen                                      float64
# Address.16.completeAddress.inputAddressSimilarityScore    float64
# Address.17.addressLine1                                    object
# Address.17.addressLine2                                    object
# Address.17.addressType                                     object
# Address.17.associatedName                                  object
# Address.17.city                                            object
# Address.17.completeAddress                                 object
# Address.17.completeAddress.addressCompletenessScore       float64
# Address.17.country                                         object
# Address.17.countryCode                                     object
# Address.17.email                                           object
# Address.17.lastDeliveryDate                                object
# Address.17.pinCode                                        float64
# Address.17.state                                           object
# Address.17.stateCode                                       object
# Address.17.timesSeen                                      float64
# Address.17.completeAddress.inputAddressSimilarityScore    float64
# Address.18.addressLine1                                    object
# Address.18.addressLine2                                    object
# Address.18.addressType                                     object
# Address.18.associatedName                                  object
# Address.18.city                                            object
# Address.18.completeAddress                                 object
# Address.18.completeAddress.addressCompletenessScore       float64
# Address.18.country                                         object
# Address.18.countryCode                                     object
# Address.18.email                                           object
# Address.18.lastDeliveryDate                               float64
# Address.18.pinCode                                        float64
# Address.18.state                                           object
# Address.18.stateCode                                      float64
# Address.18.timesSeen                                      float64
# Address.18.completeAddress.inputAddressSimilarityScore    float64
# Address.19.addressLine1                                    object
# Address.19.addressLine2                                    object
# Address.19.addressType                                     object
# Address.19.associatedName                                  object
# Address.19.city                                            object
# Address.19.completeAddress                                 object
# Address.19.completeAddress.addressCompletenessScore       float64
# Address.19.country                                         object
# Address.19.countryCode                                     object
# Address.19.email                                           object
# Address.19.lastDeliveryDate                               float64
# Address.19.pinCode                                        float64
# Address.19.state                                           object
# Address.19.stateCode                                      float64
# Address.19.timesSeen                                      float64
# Address.20.addressLine1                                    object
# Address.20.addressLine2                                    object
# Address.20.addressType                                     object
# Address.20.associatedName                                  object
# Address.20.city                                            object
# Address.20.completeAddress                                 object
# Address.20.completeAddress.addressCompletenessScore       float64
# Address.20.country                                         object
# Address.20.countryCode                                     object
# Address.20.email                                           object
# Address.20.lastDeliveryDate                               float64
# Address.20.pinCode                                        float64
# Address.20.state                                           object
# Address.20.stateCode                                      float64
# Address.20.timesSeen                                      float64
# Address.21.addressLine1                                    object
# Address.21.addressLine2                                    object
# Address.21.addressType                                     object
# Address.21.associatedName                                  object
# Address.21.city                                            object
# Address.21.completeAddress                                 object
# Address.21.completeAddress.addressCompletenessScore       float64
# Address.21.country                                         object
# Address.21.countryCode                                     object
# Address.21.email                                           object
# Address.21.lastDeliveryDate                               float64
# Address.21.pinCode                                        float64
# Address.21.state                                           object
# Address.21.stateCode                                       object
# Address.21.timesSeen                                      float64
# Address.22.addressLine1                                    object
# Address.22.addressLine2                                    object
# Address.22.addressType                                     object
# Address.22.associatedName                                  object
# Address.22.city                                            object
# Address.22.completeAddress                                 object
# Address.22.completeAddress.addressCompletenessScore       float64
# Address.22.country                                         object
# Address.22.countryCode                                     object
# Address.22.email                                           object
# Address.22.lastDeliveryDate                                object
# Address.22.pinCode                                        float64
# Address.22.state                                           object
# Address.22.stateCode                                       object
# Address.22.timesSeen                                      float64
# Address.23.addressLine1                                    object
# Address.23.addressLine2                                    object
# Address.23.addressType                                     object
# Address.23.associatedName                                  object
# Address.23.city                                            object
# Address.23.completeAddress                                 object
# Address.23.completeAddress.addressCompletenessScore       float64
# Address.23.country                                         object
# Address.23.countryCode                                     object
# Address.23.email                                           object
# Address.23.lastDeliveryDate                                object
# Address.23.pinCode                                        float64
# Address.23.state                                           object
# Address.23.stateCode                                       object
# Address.23.timesSeen                                      float64
# Address.24.addressLine1                                    object
# Address.24.addressLine2                                    object
# Address.24.addressType                                     object
# Address.24.associatedName                                  object
# Address.24.city                                            object
# Address.24.completeAddress                                 object
# Address.24.completeAddress.addressCompletenessScore       float64
# Address.24.country                                         object
# Address.24.countryCode                                     object
# Address.24.email                                           object
# Address.24.lastDeliveryDate                                object
# Address.24.pinCode                                        float64
# Address.24.state                                           object
# Address.24.stateCode                                       object
# Address.24.timesSeen                                      float64
# Address.25.addressLine1                                    object
# Address.25.addressLine2                                    object
# Address.25.addressType                                     object
# Address.25.associatedName                                  object
# Address.25.city                                            object
# Address.25.completeAddress                                 object
# Address.25.completeAddress.addressCompletenessScore       float64
# Address.25.country                                         object
# Address.25.countryCode                                     object
# Address.25.email                                           object
# Address.25.lastDeliveryDate                                object
# Address.25.pinCode                                        float64
# Address.25.state                                           object
# Address.25.stateCode                                       object
# Address.25.timesSeen                                      float64
# Address.26.addressLine1                                    object
# Address.26.addressLine2                                    object
# Address.26.addressType                                     object
# Address.26.associatedName                                  object
# Address.26.city                                            object
# Address.26.completeAddress                                 object
# Address.26.completeAddress.addressCompletenessScore       float64
# Address.26.country                                         object
# Address.26.countryCode                                     object
# Address.26.email                                           object
# Address.26.lastDeliveryDate                                object
# Address.26.pinCode                                        float64
# Address.26.state                                           object
# Address.26.stateCode                                       object
# Address.26.timesSeen                                      float64
# Address.27.addressLine1                                    object
# Address.27.addressLine2                                    object
# Address.27.addressType                                     object
# Address.27.associatedName                                  object
# Address.27.city                                            object
# Address.27.completeAddress                                 object
# Address.27.completeAddress.addressCompletenessScore       float64
# Address.27.country                                         object
# Address.27.countryCode                                     object
# Address.27.email                                           object
# Address.27.lastDeliveryDate                               float64
# Address.27.pinCode                                        float64
# Address.27.state                                           object
# Address.27.stateCode                                      float64
# Address.27.timesSeen                                      float64
# dtype: object

# %%
address_type_counts = df1['Address.3.addressType'].value_counts()

print(address_type_counts)
# Out:
# Address.3.addressType
# ['logisticsAddress']                          511
# ['transportDlAddress']                         90
# ['taxAddress']                                 44
# ['businessAddress']                             3
# ['logisticsAddress', 'transportDlAddress']      1
# Name: count, dtype: int64
